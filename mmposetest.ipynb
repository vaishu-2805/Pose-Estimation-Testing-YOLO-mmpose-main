# %%
import time
import mmpose
from mmpose.apis import MMPoseInferencer
from pathlib import Path
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image

time_res = []


def get_image_size(img_path):
    with Image.open(img_path) as img:
        width, height = img.size
    return width, height


  
def test_mmposeinter_human(img_path,num_of_h,inferencer,iterations=10):
# instantiate the inferencer using the model alias

  times = []
  num_detected_list = []   

# The MMPoseInferencer API employs a lazy inference approach,
# creating a prediction generator when given input
  for _ in range(iterations):
      start = time.perf_counter()
      result_generator = inferencer(img_path, show=False,vis_out_dir='./Results')  # turn off showing the result for speed
      result = next(result_generator)
      stop = time.perf_counter()
      
      
      detection_time = stop - start
      times.append(detection_time)
      num_detected = len(result['predictions'][0])
      num_detected_list.append(num_detected)
  
  avg_time = sum(times) / iterations
  avg_detected = sum(num_detected_list) / iterations
  print(f"Image name: {Path(img_path).name}")
  print(f"Number of humans on the image:{num_of_h}")
  print(f"Number of humans detected:{avg_detected}")
  print(f"Detection time:{avg_time} seconds")
  # nb = len(result['predictions'][0])
  return avg_time, avg_detected

size = []  
lst_err = []
nb_h_l = []
l_of_p = []
inferencer = MMPoseInferencer('human')

img_path = './InputsJPGs/humanadnanimal.jpg'
nb_of_p = 1
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group.jpg'
nb_of_p = 21
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/one.jpg'
nb_of_p = 1
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/manwithoutlimbs.jpg'
nb_of_p = 1
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group2.jpg' 
nb_of_p = 8
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

# img_path = './InputsJPGs/animallikehuman.jpg'
# t, nb_det = test_mmposeinter_human(img_path,0,inferencer)
# time_res.append(t)
# nb_h_l.append(nb_det)


img_path = './InputsJPGs/group3.jpg'
nb_of_p = 12
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)


img_path = './InputsJPGs/group4.jpg'
nb_of_p = 12
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group5.jpg'
nb_of_p = 14
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group6.jpg'
nb_of_p = 8
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group7.jpg'
nb_of_p = 6
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group8.jpg'
nb_of_p = 10
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group9.jpg'
nb_of_p = 7
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group10.jpg'
nb_of_p = 5
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group11.jpg'
nb_of_p = 6
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group12.jpg'
nb_of_p = 13
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group13.jpg'
nb_of_p = 3
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group14.jpg'
nb_of_p = 5
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group15.jpg'
nb_of_p = 5
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group16.jpg'
nb_of_p = 10
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)

img_path = './InputsJPGs/group17.jpg'
nb_of_p = 4
l_of_p.append(nb_of_p)
t, nb_det = test_mmposeinter_human(img_path,nb_of_p,inferencer)
time_res.append(t)
nb_h_l.append(nb_det)
width, height = get_image_size(img_path)
size.append(width * height)
err = abs(nb_of_p - nb_det)/nb_of_p
lst_err.append(1 - err)


plt.scatter(nb_h_l,time_res)
plt.grid()
plt.title("Time of detection depending on number of detected people")
plt.xlabel('Number of detected people')
plt.ylabel('Detection time [s]')
plt.show()

plt.scatter(size,time_res)
plt.grid()
plt.title("Time of detection depending on size of the image")
plt.xlabel('Size [pixels]')
plt.ylabel('Detection time [s]')
plt.xscale('log')
plt.show()

plt.scatter(l_of_p,lst_err)
plt.grid()
plt.title("Accuracy depending on number of people on the image")
plt.xlabel('Number of humans')
plt.ylabel('Accuracy ')
plt.show()

plt.scatter(size,lst_err)
plt.grid()
plt.title("Accuracy depending on size of the image")
plt.xlabel('Size [pixels]')
plt.ylabel('Accuracy ')
plt.xscale('log')
plt.show()
# Out:
# c:\Users\pawel\miniconda3\envs\openmmlab\lib\site-packages\mmengine\optim\optimizer\zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/rtmpose-m_simcc-body7_pt-body7_420e-256x192-e48f03d0_20230504.pth
# 10/02 12:22:15 - mmengine - WARNING - Failed to search registry with scope "mmpose" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmpose" is a correct scope, or whether the registry is initialized.
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/rtmdet_m_8xb32-100e_coco-obj365-person-235e8209.pth
# 10/02 12:22:16 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# c:\Users\pawel\miniconda3\envs\openmmlab\lib\site-packages\mmdet\models\layers\se_layer.py:158: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# c:\Users\pawel\miniconda3\envs\openmmlab\lib\site-packages\mmdet\models\backbones\csp_darknet.py:118: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 10/02 12:22:17 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# c:\Users\pawel\miniconda3\envs\openmmlab\lib\site-packages\torch\functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3610.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 10/02 12:22:17 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:17 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:18 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:18 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:19 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:19 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:19 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:20 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# 10/02 12:22:20 - mmengine - INFO - the output image has been saved at ./Results\humanadnanimal.jpg
# Image name: humanadnanimal.jpg
# Number of humans on the image:1
# Number of humans detected:1.0
# Detection time:0.36697414000009304 seconds
# 10/02 12:22:21 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:22 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:23 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:24 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:25 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:26 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:27 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:28 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:29 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# 10/02 12:22:30 - mmengine - INFO - the output image has been saved at ./Results\group.jpg
# Image name: group.jpg
# Number of humans on the image:21
# Number of humans detected:21.0
# Detection time:1.0417861200002334 seconds
# 10/02 12:22:31 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:31 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:32 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:32 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:32 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:33 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:33 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:33 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:34 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# 10/02 12:22:34 - mmengine - INFO - the output image has been saved at ./Results\one.jpg
# Image name: one.jpg
# Number of humans on the image:1
# Number of humans detected:1.0
# Detection time:0.36984903000002306 seconds
# 10/02 12:22:35 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:35 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:35 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:36 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:36 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:36 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:37 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:37 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:38 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# 10/02 12:22:38 - mmengine - INFO - the output image has been saved at ./Results\manwithoutlimbs.jpg
# Image name: manwithoutlimbs.jpg
# Number of humans on the image:1
# Number of humans detected:1.0
# Detection time:0.38418096999994306 seconds
# 10/02 12:22:39 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:39 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:40 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:40 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:40 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:41 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:41 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:42 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:42 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# 10/02 12:22:43 - mmengine - INFO - the output image has been saved at ./Results\group2.jpg
# Image name: group2.jpg
# Number of humans on the image:8
# Number of humans detected:5.0
# Detection time:0.4997058700000707 seconds
# 10/02 12:22:44 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:44 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:45 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:46 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:46 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:47 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:47 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:48 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:49 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# 10/02 12:22:49 - mmengine - INFO - the output image has been saved at ./Results\group3.jpg
# Image name: group3.jpg
# Number of humans on the image:12
# Number of humans detected:10.0
# Detection time:0.6423922499998298 seconds
# 10/02 12:22:50 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:51 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:52 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:52 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:53 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:54 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:54 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:55 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:56 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# 10/02 12:22:56 - mmengine - INFO - the output image has been saved at ./Results\group4.jpg
# Image name: group4.jpg
# Number of humans on the image:12
# Number of humans detected:12.0
# Detection time:0.7057832400000734 seconds
# 10/02 12:22:58 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:22:59 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:00 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:02 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:03 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:05 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:06 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:07 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:09 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# 10/02 12:23:10 - mmengine - INFO - the output image has been saved at ./Results\group5.jpg
# Image name: group5.jpg
# Number of humans on the image:14
# Number of humans detected:14.0
# Detection time:1.3650195199998962 seconds
# 10/02 12:23:11 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:12 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:13 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:14 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:15 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:16 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:17 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:18 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:19 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# 10/02 12:23:20 - mmengine - INFO - the output image has been saved at ./Results\group6.jpg
# Image name: group6.jpg
# Number of humans on the image:8
# Number of humans detected:8.0
# Detection time:0.9520446999999876 seconds
# 10/02 12:23:21 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:22 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:23 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:24 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:25 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:26 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:27 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:28 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:29 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# 10/02 12:23:30 - mmengine - INFO - the output image has been saved at ./Results\group7.jpg
# Image name: group7.jpg
# Number of humans on the image:6
# Number of humans detected:6.0
# Detection time:1.0785156399999323 seconds
# 10/02 12:23:31 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:33 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:34 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:35 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:36 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:37 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:38 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:39 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:40 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# 10/02 12:23:41 - mmengine - INFO - the output image has been saved at ./Results\group8.jpg
# Image name: group8.jpg
# Number of humans on the image:10
# Number of humans detected:11.0
# Detection time:1.0797537100000227 seconds
# 10/02 12:23:43 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:45 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:47 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:49 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:51 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:53 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:55 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:56 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:23:58 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# 10/02 12:24:00 - mmengine - INFO - the output image has been saved at ./Results\group9.jpg
# Image name: group9.jpg
# Number of humans on the image:7
# Number of humans detected:6.0
# Detection time:1.9152699999996912 seconds
# 10/02 12:24:01 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:02 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:03 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:04 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:04 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:05 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:06 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:07 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:08 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# 10/02 12:24:08 - mmengine - INFO - the output image has been saved at ./Results\group10.jpg
# Image name: group10.jpg
# Number of humans on the image:5
# Number of humans detected:4.0
# Detection time:0.7942143099998248 seconds
# 10/02 12:24:09 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:10 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:10 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:11 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:12 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:12 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:13 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:14 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:14 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# 10/02 12:24:15 - mmengine - INFO - the output image has been saved at ./Results\group11.jpg
# Image name: group11.jpg
# Number of humans on the image:6
# Number of humans detected:4.0
# Detection time:0.6731472999998914 seconds
# 10/02 12:24:17 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:19 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:20 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:22 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:24 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:26 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:28 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:29 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:31 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# 10/02 12:24:33 - mmengine - INFO - the output image has been saved at ./Results\group12.jpg
# Image name: group12.jpg
# Number of humans on the image:13
# Number of humans detected:12.0
# Detection time:1.8044231399999262 seconds
# 10/02 12:24:34 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:34 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:34 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:35 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:35 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:36 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:36 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:37 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:37 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# 10/02 12:24:38 - mmengine - INFO - the output image has been saved at ./Results\group13.jpg
# Image name: group13.jpg
# Number of humans on the image:3
# Number of humans detected:3.0
# Detection time:0.46279332000003703 seconds
# 10/02 12:24:40 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:41 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:43 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:45 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:47 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:49 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:51 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:52 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:54 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# 10/02 12:24:56 - mmengine - INFO - the output image has been saved at ./Results\group14.jpg
# Image name: group14.jpg
# Number of humans on the image:5
# Number of humans detected:4.0
# Detection time:1.832322860000113 seconds
# 10/02 12:24:57 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:24:58 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:24:59 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:25:00 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:25:01 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:25:01 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:25:02 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:25:03 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:25:04 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# 10/02 12:25:05 - mmengine - INFO - the output image has been saved at ./Results\group15.jpg
# Image name: group15.jpg
# Number of humans on the image:5
# Number of humans detected:5.0
# Detection time:0.9016853000001902 seconds
# 10/02 12:25:09 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:13 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:16 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:20 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:24 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:28 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:32 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:35 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:39 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# 10/02 12:25:43 - mmengine - INFO - the output image has been saved at ./Results\group16.jpg
# Image name: group16.jpg
# Number of humans on the image:10
# Number of humans detected:10.0
# Detection time:3.7987644899999395 seconds
# 10/02 12:25:45 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:25:47 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:25:49 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:25:51 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:25:53 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:25:55 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:25:57 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:25:59 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:26:01 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# 10/02 12:26:03 - mmengine - INFO - the output image has been saved at ./Results\group17.jpg
# Image name: group17.jpg
# Number of humans on the image:4
# Number of humans detected:4.0
# Detection time:2.009935979999864 seconds
